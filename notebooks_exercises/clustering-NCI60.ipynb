# %%
# the usual imports
from __future__ import division
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X = pd.read_csv('../data/NCI60_X.csv')
X = X.drop('Unnamed: 0', axis=1)

# %%
X.shape
# Out:
# (64, 6830)

# %%
X.head()
# Out:
#           1         2         3         4         5             6         7  \
# 0  0.300000  1.180000  0.550000  1.140000 -0.265000 -7.000000e-02  0.350000
# 1  0.679961  1.289961  0.169961  0.379961  0.464961  5.799610e-01  0.699961
# 2  0.940000 -0.040000 -0.170000 -0.040000 -0.605000  0.000000e+00  0.090000
# 3  0.280000 -0.310000  0.680000 -0.810000  0.625000 -1.387779e-17  0.170000
# 4  0.485000 -0.465000  0.395000  0.905000  0.200000 -5.000000e-03  0.085000
#
#           8         9        10    ...         6821      6822      6823  \
# 0 -0.315000 -0.450000 -0.654981    ...    -0.990019  0.000000  0.030000
# 1  0.724961 -0.040039 -0.285020    ...    -0.270058 -0.300039 -0.250039
# 2  0.645000  0.430000  0.475019    ...     0.319981  0.120000 -0.740000
# 3  0.245000  0.020000  0.095019    ...    -1.240020 -0.110000 -0.160000
# 4  0.110000  0.235000  1.490019    ...     0.554980 -0.775000 -0.515000
#
#        6824      6825      6826      6827      6828      6829      6830
# 0 -0.175000  0.629981 -0.030000  0.000000  0.280000 -0.340000 -1.930000
# 1 -0.535039  0.109941 -0.860039 -1.250049 -0.770039 -0.390039 -2.000039
# 2 -0.595000 -0.270020 -0.150000  0.000000 -0.120000 -0.410000  0.000000
# 3  0.095000 -0.350020 -0.300000 -1.150010  1.090000 -0.260000 -1.100000
# 4 -0.320000  0.634980  0.605000  0.000000  0.745000  0.425000  0.145000
#
# [5 rows x 6830 columns]

# %%
y = pd.read_csv('../data/NCI60_y.csv')
y = y.drop('Unnamed: 0', axis=1)

# %%
y.shape
# Out:
# (64, 1)

# %%
y
# Out:
#               x
# 0           CNS
# 1           CNS
# 2           CNS
# 3         RENAL
# 4        BREAST
# 5           CNS
# 6           CNS
# 7        BREAST
# 8         NSCLC
# 9         NSCLC
# 10        RENAL
# 11        RENAL
# 12        RENAL
# 13        RENAL
# 14        RENAL
# 15        RENAL
# 16        RENAL
# 17       BREAST
# 18        NSCLC
# 19        RENAL
# 20      UNKNOWN
# 21      OVARIAN
# 22     MELANOMA
# 23     PROSTATE
# 24      OVARIAN
# 25      OVARIAN
# 26      OVARIAN
# 27      OVARIAN
# 28      OVARIAN
# 29     PROSTATE
# ..          ...
# 34  K562B-repro
# 35  K562A-repro
# 36     LEUKEMIA
# 37     LEUKEMIA
# 38     LEUKEMIA
# 39     LEUKEMIA
# 40     LEUKEMIA
# 41        COLON
# 42        COLON
# 43        COLON
# 44        COLON
# 45        COLON
# 46        COLON
# 47        COLON
# 48  MCF7A-repro
# 49       BREAST
# 50  MCF7D-repro
# 51       BREAST
# 52        NSCLC
# 53        NSCLC
# 54        NSCLC
# 55     MELANOMA
# 56       BREAST
# 57       BREAST
# 58     MELANOMA
# 59     MELANOMA
# 60     MELANOMA
# 61     MELANOMA
# 62     MELANOMA
# 63     MELANOMA
#
# [64 rows x 1 columns]

# %%
from sklearn import preprocessing
X = preprocessing.StandardScaler().fit_transform(X)

# %%
X[:5,:10]
# Out:
# array([[ 0.72867057,  1.60722049,  1.32568834,  1.35568843, -0.60484459,
#         -0.22065404,  0.89813739, -0.86874133, -1.05861225, -1.05917363],
#        [ 1.59641782,  1.7535441 ,  0.44168566,  0.6541189 ,  0.9118982 ,
#          1.64874848,  1.84969747,  2.22662461, -0.09586008, -0.47797726],
#        [ 2.19028963, -0.01621694, -0.34909222,  0.26646532, -1.31131048,
#         -0.01932168,  0.19118541,  1.98862668,  1.00797918,  0.71601861],
